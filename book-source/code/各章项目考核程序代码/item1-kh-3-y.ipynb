# %%
#项目1-项目考核代码

import numpy as np					#激活numpy
import matplotlib.pyplot as plt	#激活matplotlib
x=np.arange(-2,0.5,0.03)			#设置x的取值范围，设置坐标值
y=x*x*x+2*x*x								#设置y值，令x*x*x+2*x*x
plt.plot(x,y,'g*')					#绘制曲线，第3个参数表示绿色星型
plt.show()							#显示图形
