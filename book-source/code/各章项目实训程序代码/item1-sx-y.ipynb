# %%
#项目1-项目实训代码

import numpy as np					#激活numpy
import matplotlib.pyplot as plt	#激活matplotlib
x=np.arange(-10,10,0.01)			#设置x的取值范围，设置坐标值
y=x*x+2*x+5								#设置y值，令y=x*x+2*x+5
plt.plot(x,y,'r--')					#绘制曲线，第3个参数表示红色虚线
plt.show()							#显示图形
